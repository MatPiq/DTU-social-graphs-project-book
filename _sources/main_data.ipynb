# %% [markdown]
# # Data Description

# %% [markdown]
# For our project, we collected wikipedia articles corresponding to five major social science diciplines: Economics, Political Science, Anthropology, Sociology and Psychology. To do this we used the tool [petscan](https://petscan.wmflabs.org/) which enables one to find all the sub-categories/articles corresponding to a given page. Petscan can be access both through a web-interface or programmatically through for example Python. We did it programmatically by querying the main page corresponding to each discipline.

# %% [markdown]
# **Insert GIF about HERE**

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from collections import defaultdict


df = pd.read_pickle('/home/matiasp/University/m2/socialgraphs2021-Matias/project/wiki_df.pickle')
df = df.drop(columns=['categories', 'depth']).dropna()
df['edges'] = df['edges'].apply(lambda x: literal_eval(x))
df.head()
# Out:
#                    name             parent  \
# 0             Anarchism  political_science
# 1  Cultural_imperialism  political_science
# 2                Census  political_science
# 3       Comparative_law  political_science
# 4     Code_of_Hammurabi  political_science
#
#                                                edges  \
# 0  [-ism, 1872 Hague Congress, 1919 United States...
# 1  [Abnormal (Foucault), Acculturation, Aesthetic...
# 2  [2011 Canadian census, Ab urbe condita (book),...
# 3  [Act of Congress, Act of Parliament, Adjudicat...
# 4  ['Ain Ghazal Statues, A. Leo Oppenheim, A Medi...
#
#                                                 text  \
# 0  Anarchism is a political philosophy and moveme...
# 1  Cultural imperialism, also called cultural col...
# 2  A census is the procedure of systematically ca...
# 3  Comparative law is the study of differences an...
# 4  The Code of Hammurabi is a Babylonian legal te...
#
#                                         cleaned_text  \
# 0  anarchism is a political philosophy and moveme...
# 1  cultural imperialism also called cultural colo...
# 2  a census is the procedure of systematically ca...
# 3  comparative law is the study of differences an...
# 4  the code of hammurabi is a babylonian legal te...
#
#                                           lemmatized  \
# 0  anarchism political philosophy movement scepti...
# 1  cultural imperialism also called cultural colo...
# 2  a census procedure systematically calculating ...
# 3  comparative law study difference similarity la...
# 4  the code hammurabi babylonian legal text compo...
#
#                                               tokens
# 0  ['anarchism', 'political', 'philosophy', 'move...
# 1  ['cultural', 'imperialism', 'also', 'called', ...
# 2  ['a', 'census', 'procedure', 'systematically',...
# 3  ['comparative', 'law', 'study', 'difference', ...
# 4  ['the', 'code', 'hammurabi', 'babylonian', 'le...

# %%
#Create descriptives table
tab = defaultdict(list)
for discipline in df['parent'].unique():
    avg_edges = []
    avg_pagelen = []
    for row in df.loc[df['parent']==discipline].iterrows():
        avg_edges.append(len(row[1]['edges']))
        avg_pagelen.append(len(row[1]['tokens']))
    
    tab['Discipline'].append(discipline)
    tab['Number of articles'].append(df.loc[df['parent']==discipline].shape[0])
    tab['Avg. edges'].append(np.mean(avg_edges))
    tab['Avg. word count'].append(np.mean(avg_pagelen))
tab = pd.DataFrame(tab)
tab.set_index('Discipline').round(2)
# Out:
#                    Number of articles  Avg. edges  Avg. word count
# Discipline
# political_science                 874      144.41          9634.81
# economics                         972       78.32          4967.01
# sociology                         990      123.47          8737.07
# anthropology                     1785      164.28          9343.31
# psychology                       1333      106.79          9327.63
